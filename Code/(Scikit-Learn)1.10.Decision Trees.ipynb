# %% [markdown]
# # 1.10. Decision Trees (User Guide in scikit-learn)
#
# ## Contents
# - [01.Introduction](#01.Introduction)
#   - [1.1.DecisionTree_Pros&Cons](#1.1.DecisionTree_Pros&Cons)
#   - [1.2.Components_of_DecisionTree](#1.2.Components_of_DecisionTree)
# - [02_Methodology](#02_Methodology)
#   - [2.1.Splitting_Rule](#2.1.Splitting_Rule)
#     - [2.1.1.Classification](#2.1.1.Classification)
#     - [2.1.2.Regression](#2.1.2.Regression)
#   - [2.2.Pruning_Rule](#2.2.Pruning_Rule)
#     - [2.2.1.Post-Pruning](#2.2.1.Post-Pruning)
#     - [2.2.2.Pre-Pruning](#2.2.2.Pre-Pruning)
# - [03.Tree_Algorithms](#03.Tree_Algorithms)
#   - [3.1.History_of_DecisionTree_Algorithms](#3.1.History_of_DecisionTree_Algorithms)
# - [04.Appendix](#04.Appendix)
#   - [4.1.Tips_on_Practical_Use](#4.1.Tips_on_Practical_Use)

# %% [markdown]
# # 01.Introduction

# %% [markdown]
# ## 1.1.DecisionTree_Pros&Cons

# %% [markdown]
# ![image.png](attachment:41ccf04b-87ea-401c-aaa1-44347203f7d7.png)

# %% [markdown]
# ## 1.2.Components_of_DecisionTree

# %% [markdown]
# ![image.png](attachment:9526c4fd-aaf2-4327-8c2e-881b9046c346.png)

# %% [markdown]
# # 02.Methodology

# %% [markdown]
# ## 2.1.Splitting_Rule

# %% [markdown]
# ![image.png](attachment:6531f53b-dc02-451d-82dd-56ee4dd375a5.png)

# %% [markdown]
# ## 2.1.1.Classification
# * _**1.10.1. Classification**_
# * **DecisionTreeClassifier** is a class capable of performing multi-class classification on a dataset.
# * Format Example : X = (`n_samples`, `n_features`), Y = (`n_samples`,)

# %%
from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)

# %%
tree.plot_tree(clf)
# Out:
# [Text(167.4, 199.32, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(141.64615384615385, 163.07999999999998, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(193.15384615384616, 163.07999999999998, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(103.01538461538462, 126.83999999999999, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(51.50769230769231, 90.6, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(25.753846153846155, 54.359999999999985, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(77.26153846153846, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(154.52307692307693, 90.6, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(128.76923076923077, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ## 2.1.2.Regression
# * _**1.10.2. Regression**_ :

# %%
from sklearn import tree
X = [[0, 0], [2, 2]]
y = [0.5, 2.5]
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X, y)
clf.predict([[1, 1]])
# Out:
# array([0.5])

# %% [markdown]
# - _**Graph Example : Decision Tree Regression**_

# %%
# Import the necessary modules and libraries
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %% [markdown]
# ## 2.2.Pruning_Rule

# %% [markdown]
# ![image.png](attachment:01095011-f2ce-4c10-ad9b-98be4659b7de.png)

# %% [markdown]
# ## 2.2.1.Post-Pruning

# %% [markdown]
# ![image.png](attachment:08567ce6-0b39-4a57-a3f6-da0df3f9e629.png)

# %% [markdown]
# ## 2.2.2.Pre-Pruning

# %% [markdown]
# ![image.png](attachment:50a56525-6d98-4292-8480-bce0d955a100.png)

# %% [markdown]
# # 03.Tree_Algorithms

# %% [markdown]
# ## 3.1.History_of_DecisionTree_Algorithms

# %% [markdown]
# ![image.png](attachment:de68dfa4-379d-4518-b8dc-2763177e02b6.png)

# %% [markdown]
# # 04.Appendix

# %% [markdown]
# ## 4.1.Tips_on_Practical_Use

# %% [markdown]
# ![image.png](attachment:af66b0ef-e88a-4fc8-b251-5b9c4c622ace.png)

# %% [markdown]
# #https://scikit-learn.org/stable/modules/decomposition.html#pca

# %% [markdown]
# - _**Glossary**_
#   - ID3 = Iteractive Dichotomiser 3
#   - CART = Classification and Regression Trees
#   - Impurity = 불순도
#   - Information Gain = 정보 이득
#   - Entropy = 복잡도
#   - Gini Impurity = 지니 불순도
